# %%
import os

import math

import numpy as np
import pandas as pd
pd.set_option('display.max_rows', 12)
pd.set_option('display.notebook_repr_html', True)
pd.set_option('display.max_columns', 12)

import statsmodels.api as sm
import statsmodels.formula.api as smf
from sklearn import preprocessing, neighbors, grid_search, linear_model, cross_validation

import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use('ggplot')

import seaborn as sns

# %%
df = pd.read_csv(os.path.join('..', 'dataset', 'winequality-red.csv'))

# %%
df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# 5               7.4             0.660         0.00             1.8      0.075
# ...             ...               ...          ...             ...        ...
# 1593            6.8             0.620         0.08             1.9      0.068
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                    11.0                  34.0  0.99780  3.51       0.56
# 1                    25.0                  67.0  0.99680  3.20       0.68
# 2                    15.0                  54.0  0.99700  3.26       0.65
# 3                    17.0                  60.0  0.99800  3.16       0.58
# 4                    11.0                  34.0  0.99780  3.51       0.56
# 5                    13.0                  40.0  0.99780  3.51       0.56
# ...                   ...                   ...      ...   ...        ...
# 1593                 28.0                  38.0  0.99651  3.42       0.82
# 1594                 32.0                  44.0  0.99490  3.45       0.58
# 1595                 39.0                  51.0  0.99512  3.52       0.76
# 1596                 29.0                  40.0  0.99574  3.42       0.75
# 1597                 32.0                  44.0  0.99547  3.57       0.71
# 1598                 18.0                  42.0  0.99549  3.39       0.66
#
#       alcohol  quality
# 0         9.4        5
# 1         9.8        5
# 2         9.8        5
# 3         9.8        6
# 4         9.4        5
# 5         9.4        5
# ...       ...      ...
# 1593      9.5        6
# 1594     10.5        5
# 1595     11.2        6
# 1596     11.0        6
# 1597     10.2        5
# 1598     11.0        6
#
# [1599 rows x 12 columns]

# %% [markdown]
# A description of the dataset is as follows:
#
#     fixed acidity in g/dm3
#     volatile acidity in g/dm3
#     citric acid in g/dm3
#     residual sugar in g/dm3
#     chlorides in g/dm3
#     free sulfur dioxide in g/dm3
#     total sulfur dioxide in g/dm3
#     density in g/cm3
#     pH
#     sulphates in g/dm3
#     alcohol in % vol.
#     quality is the rating score
#
# Quality is the dependent variable.

# %% [markdown]
# Cleaning data -
# Checking for null values in the dataset

# %%
df.isnull()
# Out:
#      fixed acidity volatile acidity citric acid residual sugar chlorides  \
# 0            False            False       False          False     False
# 1            False            False       False          False     False
# 2            False            False       False          False     False
# 3            False            False       False          False     False
# 4            False            False       False          False     False
# 5            False            False       False          False     False
# ...            ...              ...         ...            ...       ...
# 1593         False            False       False          False     False
# 1594         False            False       False          False     False
# 1595         False            False       False          False     False
# 1596         False            False       False          False     False
# 1597         False            False       False          False     False
# 1598         False            False       False          False     False
#
#      free sulfur dioxide total sulfur dioxide density     pH sulphates  \
# 0                  False                False   False  False     False
# 1                  False                False   False  False     False
# 2                  False                False   False  False     False
# 3                  False                False   False  False     False
# 4                  False                False   False  False     False
# 5                  False                False   False  False     False
# ...                  ...                  ...     ...    ...       ...
# 1593               False                False   False  False     False
# 1594               False                False   False  False     False
# 1595               False                False   False  False     False
# 1596               False                False   False  False     False
# 1597               False                False   False  False     False
# 1598               False                False   False  False     False
#
#      alcohol quality
# 0      False   False
# 1      False   False
# 2      False   False
# 3      False   False
# 4      False   False
# 5      False   False
# ...      ...     ...
# 1593   False   False
# 1594   False   False
# 1595   False   False
# 1596   False   False
# 1597   False   False
# 1598   False   False
#
# [1599 rows x 12 columns]

# %%
df.dropna()
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# 5               7.4             0.660         0.00             1.8      0.075
# ...             ...               ...          ...             ...        ...
# 1593            6.8             0.620         0.08             1.9      0.068
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                    11.0                  34.0  0.99780  3.51       0.56
# 1                    25.0                  67.0  0.99680  3.20       0.68
# 2                    15.0                  54.0  0.99700  3.26       0.65
# 3                    17.0                  60.0  0.99800  3.16       0.58
# 4                    11.0                  34.0  0.99780  3.51       0.56
# 5                    13.0                  40.0  0.99780  3.51       0.56
# ...                   ...                   ...      ...   ...        ...
# 1593                 28.0                  38.0  0.99651  3.42       0.82
# 1594                 32.0                  44.0  0.99490  3.45       0.58
# 1595                 39.0                  51.0  0.99512  3.52       0.76
# 1596                 29.0                  40.0  0.99574  3.42       0.75
# 1597                 32.0                  44.0  0.99547  3.57       0.71
# 1598                 18.0                  42.0  0.99549  3.39       0.66
#
#       alcohol  quality
# 0         9.4        5
# 1         9.8        5
# 2         9.8        5
# 3         9.8        6
# 4         9.4        5
# 5         9.4        5
# ...       ...      ...
# 1593      9.5        6
# 1594     10.5        5
# 1595     11.2        6
# 1596     11.0        6
# 1597     10.2        5
# 1598     11.0        6
#
# [1599 rows x 12 columns]

# %%
df.isnull().sum().sum()
# Out:
# 0

# %% [markdown]
# Clean data frame (no null and no duplicates)

# %%
df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# 5               7.4             0.660         0.00             1.8      0.075
# ...             ...               ...          ...             ...        ...
# 1593            6.8             0.620         0.08             1.9      0.068
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                    11.0                  34.0  0.99780  3.51       0.56
# 1                    25.0                  67.0  0.99680  3.20       0.68
# 2                    15.0                  54.0  0.99700  3.26       0.65
# 3                    17.0                  60.0  0.99800  3.16       0.58
# 4                    11.0                  34.0  0.99780  3.51       0.56
# 5                    13.0                  40.0  0.99780  3.51       0.56
# ...                   ...                   ...      ...   ...        ...
# 1593                 28.0                  38.0  0.99651  3.42       0.82
# 1594                 32.0                  44.0  0.99490  3.45       0.58
# 1595                 39.0                  51.0  0.99512  3.52       0.76
# 1596                 29.0                  40.0  0.99574  3.42       0.75
# 1597                 32.0                  44.0  0.99547  3.57       0.71
# 1598                 18.0                  42.0  0.99549  3.39       0.66
#
#       alcohol  quality
# 0         9.4        5
# 1         9.8        5
# 2         9.8        5
# 3         9.8        6
# 4         9.4        5
# 5         9.4        5
# ...       ...      ...
# 1593      9.5        6
# 1594     10.5        5
# 1595     11.2        6
# 1596     11.0        6
# 1597     10.2        5
# 1598     11.0        6
#
# [1599 rows x 12 columns]

# %%
df.columns
# Out:
# Index([u'fixed acidity', u'volatile acidity', u'citric acid',
#        u'residual sugar', u'chlorides', u'free sulfur dioxide',
#        u'total sulfur dioxide', u'density', u'pH', u'sulphates', u'alcohol',
#        u'quality'],
#       dtype='object')

# %% [markdown]
# Exploratory Data Analysis

# %%
df.quality.max()
# Out:
# 8

# %%
df.quality.min()
# Out:
# 3

# %%
df.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# min       0.012000             1.000000              6.000000     0.990070
# 25%       0.070000             7.000000             22.000000     0.995600
# 50%       0.079000            14.000000             38.000000     0.996750
# 75%       0.090000            21.000000             62.000000     0.997835
# max       0.611000            72.000000            289.000000     1.003690
#
#                 pH    sulphates      alcohol      quality
# count  1599.000000  1599.000000  1599.000000  1599.000000
# mean      3.311113     0.658149    10.422983     5.636023
# std       0.154386     0.169507     1.065668     0.807569
# min       2.740000     0.330000     8.400000     3.000000
# 25%       3.210000     0.550000     9.500000     5.000000
# 50%       3.310000     0.620000    10.200000     6.000000
# 75%       3.400000     0.730000    11.100000     6.000000
# max       4.010000     2.000000    14.900000     8.000000

# %%
df.quality.median()
# Out:
# 6.0

# %%
df[df.quality == df.quality.max()]
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 267             7.9              0.35         0.46             3.6      0.078
# 278            10.3              0.32         0.45             6.4      0.073
# 390             5.6              0.85         0.05             1.4      0.045
# 440            12.6              0.31         0.72             2.2      0.072
# 455            11.3              0.62         0.67             5.2      0.086
# 481             9.4              0.30         0.56             2.8      0.080
# ...             ...               ...          ...             ...        ...
# 1120            7.9              0.54         0.34             2.5      0.076
# 1202            8.6              0.42         0.39             1.8      0.068
# 1269            5.5              0.49         0.03             1.8      0.044
# 1403            7.2              0.33         0.33             1.7      0.061
# 1449            7.2              0.38         0.31             2.0      0.056
# 1549            7.4              0.36         0.30             1.8      0.074
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 267                  15.0                  37.0  0.99730  3.35       0.86
# 278                   5.0                  13.0  0.99760  3.23       0.82
# 390                  12.0                  88.0  0.99240  3.56       0.82
# 440                   6.0                  29.0  0.99870  2.88       0.82
# 455                   6.0                  19.0  0.99880  3.22       0.69
# 481                   6.0                  17.0  0.99640  3.15       0.92
# ...                   ...                   ...      ...   ...        ...
# 1120                  8.0                  17.0  0.99235  3.20       0.72
# 1202                  6.0                  12.0  0.99516  3.35       0.69
# 1269                 28.0                  87.0  0.99080  3.50       0.82
# 1403                  3.0                  13.0  0.99600  3.23       1.10
# 1449                 15.0                  29.0  0.99472  3.23       0.76
# 1549                 17.0                  24.0  0.99419  3.24       0.70
#
#       alcohol  quality
# 267      12.8        8
# 278      12.6        8
# 390      12.9        8
# 440       9.8        8
# 455      13.4        8
# 481      11.7        8
# ...       ...      ...
# 1120     13.1        8
# 1202     11.7        8
# 1269     14.0        8
# 1403     10.0        8
# 1449     11.3        8
# 1549     11.4        8
#
# [18 rows x 12 columns]

# %%
df[df.quality == df.quality.min()]
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 459            11.6             0.580         0.66            2.20      0.074
# 517            10.4             0.610         0.49            2.10      0.200
# 690             7.4             1.185         0.00            4.25      0.097
# 832            10.4             0.440         0.42            1.50      0.145
# 899             8.3             1.020         0.02            3.40      0.084
# 1299            7.6             1.580         0.00            2.10      0.137
# 1374            6.8             0.815         0.00            1.20      0.267
# 1469            7.3             0.980         0.05            2.10      0.061
# 1478            7.1             0.875         0.05            5.70      0.082
# 1505            6.7             0.760         0.02            1.80      0.078
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 459                  10.0                  47.0  1.00080  3.25       0.57
# 517                   5.0                  16.0  0.99940  3.16       0.63
# 690                   5.0                  14.0  0.99660  3.63       0.54
# 832                  34.0                  48.0  0.99832  3.38       0.86
# 899                   6.0                  11.0  0.99892  3.48       0.49
# 1299                  5.0                   9.0  0.99476  3.50       0.40
# 1374                 16.0                  29.0  0.99471  3.32       0.51
# 1469                 20.0                  49.0  0.99705  3.31       0.55
# 1478                  3.0                  14.0  0.99808  3.40       0.52
# 1505                  6.0                  12.0  0.99600  3.55       0.63
#
#       alcohol  quality
# 459      9.00        3
# 517      8.40        3
# 690     10.70        3
# 832      9.90        3
# 899     11.00        3
# 1299    10.90        3
# 1374     9.80        3
# 1469     9.70        3
# 1478    10.20        3
# 1505     9.95        3

# %% [markdown]
# Finding correlation

# %%
df.corr()
# Out:
#                       fixed acidity  volatile acidity  citric acid  \
# fixed acidity              1.000000         -0.256131     0.671703
# volatile acidity          -0.256131          1.000000    -0.552496
# citric acid                0.671703         -0.552496     1.000000
# residual sugar             0.114777          0.001918     0.143577
# chlorides                  0.093705          0.061298     0.203823
# free sulfur dioxide       -0.153794         -0.010504    -0.060978
# total sulfur dioxide      -0.113181          0.076470     0.035533
# density                    0.668047          0.022026     0.364947
# pH                        -0.682978          0.234937    -0.541904
# sulphates                  0.183006         -0.260987     0.312770
# alcohol                   -0.061668         -0.202288     0.109903
# quality                    0.124052         -0.390558     0.226373
#
#                       residual sugar  chlorides  free sulfur dioxide  \
# fixed acidity               0.114777   0.093705            -0.153794
# volatile acidity            0.001918   0.061298            -0.010504
# citric acid                 0.143577   0.203823            -0.060978
# residual sugar              1.000000   0.055610             0.187049
# chlorides                   0.055610   1.000000             0.005562
# free sulfur dioxide         0.187049   0.005562             1.000000
# total sulfur dioxide        0.203028   0.047400             0.667666
# density                     0.355283   0.200632            -0.021946
# pH                         -0.085652  -0.265026             0.070377
# sulphates                   0.005527   0.371260             0.051658
# alcohol                     0.042075  -0.221141            -0.069408
# quality                     0.013732  -0.128907            -0.050656
#
#                       total sulfur dioxide   density        pH  sulphates  \
# fixed acidity                    -0.113181  0.668047 -0.682978   0.183006
# volatile acidity                  0.076470  0.022026  0.234937  -0.260987
# citric acid                       0.035533  0.364947 -0.541904   0.312770
# residual sugar                    0.203028  0.355283 -0.085652   0.005527
# chlorides                         0.047400  0.200632 -0.265026   0.371260
# free sulfur dioxide               0.667666 -0.021946  0.070377   0.051658
# total sulfur dioxide              1.000000  0.071269 -0.066495   0.042947
# density                           0.071269  1.000000 -0.341699   0.148506
# pH                               -0.066495 -0.341699  1.000000  -0.196648
# sulphates                         0.042947  0.148506 -0.196648   1.000000
# alcohol                          -0.205654 -0.496180  0.205633   0.093595
# quality                          -0.185100 -0.174919 -0.057731   0.251397
#
#                        alcohol   quality
# fixed acidity        -0.061668  0.124052
# volatile acidity     -0.202288 -0.390558
# citric acid           0.109903  0.226373
# residual sugar        0.042075  0.013732
# chlorides            -0.221141 -0.128907
# free sulfur dioxide  -0.069408 -0.050656
# total sulfur dioxide -0.205654 -0.185100
# density              -0.496180 -0.174919
# pH                    0.205633 -0.057731
# sulphates             0.093595  0.251397
# alcohol               1.000000  0.476166
# quality               0.476166  1.000000

# %% [markdown]
# From the table above, alcohol, sulphates,citric acid, and fixed acidity are highly correlated with quality

# %%
df.var()
# Out:
# fixed acidity              3.031416
# volatile acidity           0.032062
# citric acid                0.037947
# residual sugar             1.987897
# chlorides                  0.002215
# free sulfur dioxide      109.414884
# total sulfur dioxide    1082.102373
# density                    0.000004
# pH                         0.023835
# sulphates                  0.028733
# alcohol                    1.135647
# quality                    0.652168
# dtype: float64

# %%
df.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x11d8bd610>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11de00c90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11dbd4250>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x11def1750>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11df73b10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11e100290>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x11e183310>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11e1e80d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11e266150>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x11e29f310>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11e433350>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11e4b52d0>]], dtype=object)

# %%
df.quality.hist()

# %% [markdown]
# Training/Test split

# %%
X = df.drop('quality', axis= 1)

# %%
X
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# 5               7.4             0.660         0.00             1.8      0.075
# ...             ...               ...          ...             ...        ...
# 1593            6.8             0.620         0.08             1.9      0.068
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                    11.0                  34.0  0.99780  3.51       0.56
# 1                    25.0                  67.0  0.99680  3.20       0.68
# 2                    15.0                  54.0  0.99700  3.26       0.65
# 3                    17.0                  60.0  0.99800  3.16       0.58
# 4                    11.0                  34.0  0.99780  3.51       0.56
# 5                    13.0                  40.0  0.99780  3.51       0.56
# ...                   ...                   ...      ...   ...        ...
# 1593                 28.0                  38.0  0.99651  3.42       0.82
# 1594                 32.0                  44.0  0.99490  3.45       0.58
# 1595                 39.0                  51.0  0.99512  3.52       0.76
# 1596                 29.0                  40.0  0.99574  3.42       0.75
# 1597                 32.0                  44.0  0.99547  3.57       0.71
# 1598                 18.0                  42.0  0.99549  3.39       0.66
#
#       alcohol
# 0         9.4
# 1         9.8
# 2         9.8
# 3         9.8
# 4         9.4
# 5         9.4
# ...       ...
# 1593      9.5
# 1594     10.5
# 1595     11.2
# 1596     11.0
# 1597     10.2
# 1598     11.0
#
# [1599 rows x 11 columns]

# %%
y = df.quality

# %%
y
# Out:
# 0       5
# 1       5
# 2       5
# 3       6
# 4       5
# 5       5
#        ..
# 1593    6
# 1594    5
# 1595    6
# 1596    6
# 1597    5
# 1598    6
# Name: quality, dtype: int64

# %%
X_train, X_test, y_train, y_test = cross_validation.train_test_split(X, y, test_size=0.4, random_state=0)

# %%
print len (X_train)
print len (X_test)
print len (y_train)
print len (y_test)
# Out:
# 959
# 640
# 959
# 640

# %% [markdown]
# Working with training set total of 815 data points

# %%
X_train.corr()
# Out:
#                       fixed acidity  volatile acidity  citric acid  \
# fixed acidity              1.000000         -0.256652     0.672577
# volatile acidity          -0.256652          1.000000    -0.545274
# citric acid                0.672577         -0.545274     1.000000
# residual sugar             0.132647          0.002943     0.161045
# chlorides                  0.070446          0.064503     0.228408
# free sulfur dioxide       -0.162774         -0.012436    -0.074180
# total sulfur dioxide      -0.124510          0.075221     0.020590
# density                    0.649669          0.039969     0.352202
# pH                        -0.672084          0.241807    -0.552012
# sulphates                  0.175937         -0.248446     0.331401
# alcohol                   -0.056035         -0.210668     0.112173
#
#                       residual sugar  chlorides  free sulfur dioxide  \
# fixed acidity               0.132647   0.070446            -0.162774
# volatile acidity            0.002943   0.064503            -0.012436
# citric acid                 0.161045   0.228408            -0.074180
# residual sugar              1.000000   0.079736             0.250969
# chlorides                   0.079736   1.000000             0.019048
# free sulfur dioxide         0.250969   0.019048             1.000000
# total sulfur dioxide        0.233797   0.046732             0.662044
# density                     0.408947   0.187069             0.021907
# pH                         -0.115284  -0.266020             0.069676
# sulphates                   0.009864   0.397159             0.041214
# alcohol                    -0.004535  -0.204521            -0.114230
#
#                       total sulfur dioxide   density        pH  sulphates  \
# fixed acidity                    -0.124510  0.649669 -0.672084   0.175937
# volatile acidity                  0.075221  0.039969  0.241807  -0.248446
# citric acid                       0.020590  0.352202 -0.552012   0.331401
# residual sugar                    0.233797  0.408947 -0.115284   0.009864
# chlorides                         0.046732  0.187069 -0.266020   0.397159
# free sulfur dioxide               0.662044  0.021907  0.069676   0.041214
# total sulfur dioxide              1.000000  0.084709 -0.085698   0.056169
# density                           0.084709  1.000000 -0.339101   0.150905
# pH                               -0.085698 -0.339101  1.000000  -0.230914
# sulphates                         0.056169  0.150905 -0.230914   1.000000
# alcohol                          -0.220744 -0.495091  0.215999   0.085928
#
#                        alcohol
# fixed acidity        -0.056035
# volatile acidity     -0.210668
# citric acid           0.112173
# residual sugar       -0.004535
# chlorides            -0.204521
# free sulfur dioxide  -0.114230
# total sulfur dioxide -0.220744
# density              -0.495091
# pH                    0.215999
# sulphates             0.085928
# alcohol               1.000000

# %% [markdown]
# Scatter plot for each of one of varialbe

# %%
df[ ['quality', 'chlorides'] ].plot(kind = 'scatter', x = 'quality', y = 'chlorides', s = 100, figsize = (8, 8))

# %%
df[ ['quality', 'volatile acidity'] ].plot(kind = 'scatter', x = 'quality', y = 'volatile acidity', s = 100, figsize = (8, 8))

# %%
df[ ['quality', 'alcohol'] ].plot(kind = 'scatter', x = 'quality', y = 'alcohol', s = 100, figsize = (8, 8))

# %%
df[ ['quality', 'sulphates'] ].plot(kind = 'scatter', x = 'quality', y = 'sulphates', s = 100, figsize = (8, 8))

# %%
df[ ['quality', 'citric acid'] ].plot(kind = 'scatter', x = 'quality', y = 'citric acid', s = 100, figsize = (8, 8))

# %%
df[ ['quality', 'fixed acidity'] ].plot(kind = 'scatter', x = 'quality', y = 'fixed acidity', s = 100, figsize = (8, 8))

# %%
pd.tools.plotting.scatter_matrix(df[ ['quality', 'sulphates'] ], diagonal = 'kde', s = 500, figsize = (8, 8))
#pd.tools.plotting.scatter_matrix(df[ ['quality', 'sulphates'] ], s = 200, figsize = (8, 8))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x11c790290>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11caed290>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x11cb70110>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11cbd0a10>]], dtype=object)

# %% [markdown]
# check for outliers

# %%
df[ ['sulphates', 'citric acid'] ].plot(kind = 'box', figsize = (10, 10))

# %%
df[ ['alcohol', 'fixed acidity'] ].plot(kind = 'box', figsize = (8, 8))

# %% [markdown]
# Logistic Regression
# X is already defined as all the variables
# Y is quality

# %%
X_train
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 117             7.8             0.560         0.12             2.0      0.082
# 991             7.1             0.340         0.28             2.0      0.082
# 252            11.1             0.350         0.48             3.1      0.090
# 507            11.2             0.670         0.55             2.3      0.084
# 1587            5.8             0.610         0.11             1.8      0.066
# 311             7.9             0.530         0.24             2.0      0.072
# ...             ...               ...          ...             ...        ...
# 1383            8.0             0.600         0.22             2.1      0.080
# 763             9.3             0.655         0.26             2.0      0.096
# 835             7.6             0.665         0.10             1.5      0.066
# 1216            7.9             0.570         0.31             2.0      0.079
# 559            13.0             0.470         0.49             4.3      0.085
# 684             9.8             0.980         0.32             2.3      0.078
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 117                   7.0                  28.0  0.99700  3.37       0.50
# 991                  31.0                  68.0  0.99694  3.45       0.48
# 252                   5.0                  21.0  0.99860  3.17       0.53
# 507                   6.0                  13.0  1.00000  3.17       0.71
# 1587                 18.0                  28.0  0.99483  3.55       0.66
# 311                  15.0                 105.0  0.99600  3.27       0.54
# ...                   ...                   ...      ...   ...        ...
# 1383                 25.0                 105.0  0.99613  3.30       0.49
# 763                   5.0                  35.0  0.99738  3.25       0.42
# 835                  27.0                  55.0  0.99655  3.39       0.51
# 1216                 10.0                  79.0  0.99677  3.29       0.69
# 559                   6.0                  47.0  1.00210  3.30       0.68
# 684                  35.0                 152.0  0.99800  3.25       0.48
#
#       alcohol
# 117       9.4
# 991       9.4
# 252      10.5
# 507       9.5
# 1587     10.9
# 311       9.4
# ...       ...
# 1383      9.9
# 763       9.6
# 835       9.3
# 1216      9.5
# 559      12.7
# 684       9.4
#
# [959 rows x 11 columns]

# %%
y_train
# Out:
# 117     6
# 991     5
# 252     5
# 507     6
# 1587    6
# 311     6
#        ..
# 1383    5
# 763     5
# 835     5
# 1216    6
# 559     6
# 684     5
# Name: quality, dtype: int64

# %%
y_train.shape
# Out:
# (959,)
